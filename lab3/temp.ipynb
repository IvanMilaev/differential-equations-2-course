# %%
import pylab as pl
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
# варіант 8



# task 2.1
def vectorField():
    X,Y = pl.meshgrid(np.arange(-4, 5),np.arange(-4, 5))
    pl.quiver(X,Y)
    pl.title('vector field')
    pl.show() # визуализируем
    pl.savefig('task2_1.png')
    return
vectorField()

# %%
def g(y,x):
    dydx = y**2-1
    return dydx

y0 = 0
x = np.linspace(-5,5)
y = odeint(g,y0,x)

plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
def vectorField():
    x = np.linspace(-4.0, 4.0, 20)
    y = np.linspace(-4.0, 4.0, 20)
    Y = odeint(g,y0,X)
    pl.quiver(*pl.meshgrid(X,Y))
    pl.title('vector field')
    pl.show() # визуализируем
    pl.savefig('task2_1.png')
    return
vectorField()

# %%
y1 = np.linspace(-2.0, 8.0, 20)
y2 = np.linspace(-2.0, 2.0, 20)

Y1, Y2 = np.meshgrid(y1, y2)

t = 0

u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

NI, NJ = Y1.shape
